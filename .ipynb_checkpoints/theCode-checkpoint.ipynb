# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Importing the Datasets

# %%
roadDistance = pd.read_csv('Dataset/RoadDistance.csv')
straightDistance = pd.read_csv('Dataset/StraightDistance.csv')

# %% [markdown]
# ### Pre-processing the datasets

# %%
roadDistance.index = roadDistance["Unnamed: 0"]
roadDistance.drop(["Unnamed: 0"], axis=1, inplace=True)
roadDistance.index.name = ''
##########
straightDistance.index = straightDistance["Unnamed: 0"]
straightDistance.drop(["Unnamed: 0"], axis=1, inplace=True)
straightDistance.index.name = ''

# %% [markdown]
# ### Datasets after preprocessing

# %%
# straightDistance.head()
roadDistance.head()
# Out:
#                      PashupatinathTemple  BoudhanathStupa  SwayambhunathStupa  \
#
# PashupatinathTemple                  0.0              2.1                 7.5
# BoudhanathStupa                      2.1              0.0                 9.1
# SwayambhunathStupa                   7.5              9.1                 0.0
# Thamel                               4.1              5.7                 3.7
# HanumanDhokaTemple                   5.0              6.8                 3.2
#
#                      Thamel  HanumanDhokaTemple  BuddhaNilkanth  IndraChowk  \
#
# PashupatinathTemple     4.1                 5.0             8.8        4.80
# BoudhanathStupa         5.7                 6.8             7.4        6.50
# SwayambhunathStupa      3.7                 3.2            12.9        3.20
# Thamel                  0.0                 1.6             9.5        1.60
# HanumanDhokaTemple      1.6                 0.0            10.8        0.29
#
#                      DakshinkaliTemple  NationalBotanicalGardens  \
#
# PashupatinathTemple               22.9                      18.1
# BoudhanathStupa                   24.6                      19.9
# SwayambhunathStupa                21.7                      19.7
# Thamel                            21.3                      18.1
# HanumanDhokaTemple                19.3                      16.7
#
#                      SetoMachendranathTemple  ...  PatanDurbarSquare  \
#                                               ...
# PashupatinathTemple                      4.6  ...                6.5
# BoudhanathStupa                          6.4  ...                8.3
# SwayambhunathStupa                       3.4  ...                8.0
# Thamel                                   1.8  ...                5.9
# HanumanDhokaTemple                       0.4  ...                5.1
#
#                      Nagarkot  Chandragiri  Bhaktapur  Dhulikhel  Kirtipur  \
#
# PashupatinathTemple      19.6         15.7       13.4       29.4      12.1
# BoudhanathStupa          24.3         17.6       12.9       29.2      13.7
# SwayambhunathStupa       30.2         10.7       18.2       34.0       9.4
# Thamel                   27.4         12.5       17.0       31.2       9.3
# HanumanDhokaTemple       26.7         10.5       15.4       31.3       7.2
#
#                      Phulchoki  Kulekhani  NamoBuddha  Kakani
#
# PashupatinathTemple       29.0       49.4        40.5    25.9
# BoudhanathStupa           30.8       48.8        40.6    27.1
# SwayambhunathStupa        31.0       42.7        44.5    22.4
# Thamel                    29.1       44.0        42.3    23.5
# HanumanDhokaTemple        28.5       42.0        41.6    24.5
#
# [5 rows x 23 columns]

# %%
place = 'PashupatinathTemple'

for place in roadDistance.index:
    fig, ax = plt.subplots()

    # ax.set_xlabel("places")
    ax.set_ylabel("Distance (km)")
    ax.set_title(f'Distance Graph For {place}')



    ax.plot(roadDistance[place], label ='Road Distance')
    ax.plot(straightDistance[place], label ='Straight Distance')

    plt.xticks(rotation=90)

    leg = ax.legend(loc ="upper left");
# Out:
# /var/folders/p7/54dkn_ld343134xxc53cb69m0000gn/T/ipykernel_8897/1943278777.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %%
def getDistance(df, from_, to_):
    return df.loc[from_][to_]

# %%
getDistance(roadDistance, 'Thamel', 'Nagarkot')
# Out:
# 27.4

# %%
straightDistance.iloc[0, 4]
# Out:
# 4.12

# %%
class Greedy:
    def __init__(self, adjMat, heuristicMat, from_, to_):
        self.adjMat = adjMat
        self.from_ = from_
        self.to_ = to_
        self.heuristicMat = heuristicMat
        
        self.visited = [self.from_]
        self.costs = [0]
        
        f = self.from_
        
        
        for count in range(2000):
            print(f'Current Node: {f}\nVisited Nodes: {self.visited}\nCosts: {self.costs}\nTotal Cost = {sum(self.costs)}\n')
            if f == to_:
                break
            # for node in straightDistance[f].sort_values().index[1:]: # Change here
                
            for node in self.adjMat[f].sort_values().index[1:]: 
                if node not in self.visited:
                    self.visited.append(node)
                    self.costs.append(getDistance(self.adjMat, f, node))
                    f = node
                    break
        
#         for i in adjMat.index:
#             for j in adjMat.index:
#                 if i != j:
#                     dis = getDis tance(adjMat, i, j) 
#                     if dis > 55:
#                         dis = 'inf'
#                     print(f'{i} -> {j}  \n{dis}')
G = Greedy(roadDistance, straightDistance, 'Thamel', 'Nagarkot')
# Out:
# Current Node: Thamel
# Visited Nodes: ['Thamel']
# Costs: [0]
# Total Cost = 0
#
# Current Node: BasantapurTower
# Visited Nodes: ['Thamel', 'BasantapurTower']
# Costs: [0, 1.6]
# Total Cost = 1.6
#
# Current Node: HanumanDhokaTemple
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple']
# Costs: [0, 1.6, 0.13]
# Total Cost = 1.73
#
# Current Node: IndraChowk
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk']
# Costs: [0, 1.6, 0.13, 0.29]
# Total Cost = 2.02
#
# Current Node: SetoMachendranathTemple
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple']
# Costs: [0, 1.6, 0.13, 0.29, 0.1]
# Total Cost = 2.12
#
# Current Node: RatnaPark
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55]
# Total Cost = 2.67
#
# Current Node: SinghaDurbar
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1]
# Total Cost = 4.77
#
# Current Node: PatanDurbarSquare
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar', 'PatanDurbarSquare']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1, 4.0]
# Total Cost = 8.77
#
# Current Node: PashupatinathTemple
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar', 'PatanDurbarSquare', 'PashupatinathTemple']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1, 4.0, 6.5]
# Total Cost = 15.27
#
# Current Node: BoudhanathStupa
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar', 'PatanDurbarSquare', 'PashupatinathTemple', 'BoudhanathStupa']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1, 4.0, 6.5, 2.1]
# Total Cost = 17.37
#
# Current Node: BuddhaNilkanth
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar', 'PatanDurbarSquare', 'PashupatinathTemple', 'BoudhanathStupa', 'BuddhaNilkanth']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1, 4.0, 6.5, 2.1, 7.4]
# Total Cost = 24.770000000000003
#
# Current Node: SwayambhunathStupa
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar', 'PatanDurbarSquare', 'PashupatinathTemple', 'BoudhanathStupa', 'BuddhaNilkanth', 'SwayambhunathStupa']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1, 4.0, 6.5, 2.1, 7.4, 12.9]
# Total Cost = 37.67
#
# Current Node: Kirtipur
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar', 'PatanDurbarSquare', 'PashupatinathTemple', 'BoudhanathStupa', 'BuddhaNilkanth', 'SwayambhunathStupa', 'Kirtipur']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1, 4.0, 6.5, 2.1, 7.4, 12.9, 9.4]
# Total Cost = 47.07
#
# Current Node: Chandragiri
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar', 'PatanDurbarSquare', 'PashupatinathTemple', 'BoudhanathStupa', 'BuddhaNilkanth', 'SwayambhunathStupa', 'Kirtipur', 'Chandragiri']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1, 4.0, 6.5, 2.1, 7.4, 12.9, 9.4, 9.6]
# Total Cost = 56.67
#
# Current Node: NationalBotanicalGardens
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar', 'PatanDurbarSquare', 'PashupatinathTemple', 'BoudhanathStupa', 'BuddhaNilkanth', 'SwayambhunathStupa', 'Kirtipur', 'Chandragiri', 'NationalBotanicalGardens']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1, 4.0, 6.5, 2.1, 7.4, 12.9, 9.4, 9.6, 23.2]
# Total Cost = 79.87
#
# Current Node: Phulchoki
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar', 'PatanDurbarSquare', 'PashupatinathTemple', 'BoudhanathStupa', 'BuddhaNilkanth', 'SwayambhunathStupa', 'Kirtipur', 'Chandragiri', 'NationalBotanicalGardens', 'Phulchoki']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1, 4.0, 6.5, 2.1, 7.4, 12.9, 9.4, 9.6, 23.2, 11.4]
# Total Cost = 91.27000000000001
#
# Current Node: Bhaktapur
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar', 'PatanDurbarSquare', 'PashupatinathTemple', 'BoudhanathStupa', 'BuddhaNilkanth', 'SwayambhunathStupa', 'Kirtipur', 'Chandragiri', 'NationalBotanicalGardens', 'Phulchoki', 'Bhaktapur']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1, 4.0, 6.5, 2.1, 7.4, 12.9, 9.4, 9.6, 23.2, 11.4, 32.8]
# Total Cost = 124.07000000000001
#
# Current Node: Nagarkot
# Visited Nodes: ['Thamel', 'BasantapurTower', 'HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple', 'RatnaPark', 'SinghaDurbar', 'PatanDurbarSquare', 'PashupatinathTemple', 'BoudhanathStupa', 'BuddhaNilkanth', 'SwayambhunathStupa', 'Kirtipur', 'Chandragiri', 'NationalBotanicalGardens', 'Phulchoki', 'Bhaktapur', 'Nagarkot']
# Costs: [0, 1.6, 0.13, 0.29, 0.1, 0.55, 2.1, 4.0, 6.5, 2.1, 7.4, 12.9, 9.4, 9.6, 23.2, 11.4, 32.8, 12.3]
# Total Cost = 136.37

# %%
roadDistance['Phulchoki'].sort_values()
# Out:
# Phulchoki                    0.0
# NationalBotanicalGardens    11.4
# PatanDurbarSquare           22.8
# SinghaDurbar                26.6
# Kirtipur                    27.3
# IndraChowk                  27.6
# RatnaPark                   27.8
# BasantapurTower             28.1
# HanumanDhokaTemple          28.5
# SetoMachendranathTemple     28.7
# PashupatinathTemple         29.0
# Thamel                      29.1
# BoudhanathStupa             30.8
# SwayambhunathStupa          31.0
# Bhaktapur                   32.8
# Chandragiri                 34.2
# BuddhaNilkanth              37.1
# DakshinkaliTemple           37.1
# Nagarkot                    44.6
# Dhulikhel                   48.4
# NamoBuddha                  55.2
# Kakani                      59.3
# Kulekhani                   61.7
# Name: Phulchoki, dtype: float64

# %%
roadDistance['BoudhanathStupa'].sort_values()
# Out:
# BoudhanathStupa              0.0
# PashupatinathTemple          2.1
# Thamel                       5.7
# SinghaDurbar                 6.3
# SetoMachendranathTemple      6.4
# IndraChowk                   6.5
# HanumanDhokaTemple           6.8
# RatnaPark                    7.1
# BuddhaNilkanth               7.4
# BasantapurTower              7.5
# PatanDurbarSquare            8.3
# SwayambhunathStupa           9.1
# Bhaktapur                   12.9
# Kirtipur                    13.7
# Chandragiri                 17.6
# NationalBotanicalGardens    19.9
# Nagarkot                    24.3
# DakshinkaliTemple           24.6
# Kakani                      27.1
# Dhulikhel                   29.2
# Phulchoki                   30.8
# NamoBuddha                  40.6
# Kulekhani                   48.8
# Name: BoudhanathStupa, dtype: float64
