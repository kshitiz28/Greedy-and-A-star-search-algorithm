# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# ## Importing the Datasets

# %%
roadDistance = pd.read_csv('Dataset/RoadDistance.csv')
straightDistance = pd.read_csv('Dataset/StraightDistance.csv')

# %% [markdown]
# ### Pre-processing the datasets

# %%
roadDistance.index = roadDistance["Unnamed: 0"]
roadDistance.drop(["Unnamed: 0"], axis=1, inplace=True)
roadDistance.index.name = ''
##########
straightDistance.index = straightDistance["Unnamed: 0"]
straightDistance.drop(["Unnamed: 0"], axis=1, inplace=True)
straightDistance.index.name = ''

# %% [markdown]
# ### Datasets after preprocessing

# %%
# straightDistance.head()
roadDistance.head()
# Out:
#                      PashupatinathTemple  BoudhanathStupa  SwayambhunathStupa  \
#
# PashupatinathTemple                  0.0              2.1                 NaN
# BoudhanathStupa                      2.1              0.0                 NaN
# SwayambhunathStupa                   NaN              NaN                 0.0
# Thamel                               NaN              NaN                 NaN
# HanumanDhokaTemple                   5.0              NaN                 3.2
#
#                      Thamel  HanumanDhokaTemple  BuddhaNilkanth  IndraChowk  \
#
# PashupatinathTemple     NaN                 5.0             8.8         NaN
# BoudhanathStupa         NaN                 NaN             7.4         NaN
# SwayambhunathStupa      NaN                 3.2             NaN         NaN
# Thamel                  0.0                 1.6             NaN        1.60
# HanumanDhokaTemple      1.6                 0.0             NaN        0.29
#
#                      DakshinkaliTemple  NationalBotanicalGardens  \
#
# PashupatinathTemple                NaN                       NaN
# BoudhanathStupa                    NaN                       NaN
# SwayambhunathStupa                21.7                       NaN
# Thamel                             NaN                       NaN
# HanumanDhokaTemple                19.3                      16.7
#
#                      SetoMachendranathTemple  ...  PatanDurbarSquare  \
#                                               ...
# PashupatinathTemple                      NaN  ...                NaN
# BoudhanathStupa                          NaN  ...                NaN
# SwayambhunathStupa                       NaN  ...                NaN
# Thamel                                   1.8  ...                NaN
# HanumanDhokaTemple                       NaN  ...                NaN
#
#                      Nagarkot  Chandragiri  Bhaktapur  Dhulikhel  Kirtipur  \
#
# PashupatinathTemple       NaN          NaN       13.4        NaN       NaN
# BoudhanathStupa           NaN          NaN        NaN        NaN       NaN
# SwayambhunathStupa        NaN         10.7        NaN        NaN       9.4
# Thamel                    NaN          NaN        NaN        NaN       NaN
# HanumanDhokaTemple        NaN          NaN        NaN        NaN       NaN
#
#                      Phulchoki  Kulekhani  NamoBuddha  Kakani
#
# PashupatinathTemple        NaN        NaN         NaN     NaN
# BoudhanathStupa            NaN        NaN         NaN     NaN
# SwayambhunathStupa         NaN        NaN         NaN     NaN
# Thamel                     NaN        NaN         NaN     NaN
# HanumanDhokaTemple         NaN        NaN         NaN     NaN
#
# [5 rows x 23 columns]

# %%
place = 'PashupatinathTemple'

for place in roadDistance.index:
    fig, ax = plt.subplots()

    # ax.set_xlabel("places")
    ax.set_ylabel("Distance (km)")
    ax.set_title(f'Distance Graph For {place}')



    ax.plot(roadDistance[place], label ='Road Distance')
    ax.plot(straightDistance[place], label ='Straight Distance')

    plt.xticks(rotation=90)

    leg = ax.legend(loc ="upper left");
# Out:
# /var/folders/p7/54dkn_ld343134xxc53cb69m0000gn/T/ipykernel_10977/1943278777.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %%
def getDistance(df, from_, to_):
    dis = df.loc[from_][to_]
    return dis

# %%
getDistance(roadDistance, 'Thamel', 'Nagarkot')
# Out:
# nan

# %%
straightDistance.iloc[0, 4]
# Out:
# 4.12

# %%
class Greedy:
    def __init__(self, adjMat, heuristicMat, from_, to_):
        self.adjMat = adjMat
        self.from_ = from_
        self.to_ = to_
        self.heuristicMat = heuristicMat
        self.shortDistances = self.createShortestDistanceDf()
        
        self.visited = [self.from_]
        self.costs = [0]
        self.mainAlgorithm()
    
    def mainAlgorithm(self):
        currentNode = self.from_
        self.visited = [currentNode]
        for step in range(25):
            nextNodes = roadDistance[[currentNode]].query(f"{currentNode} > 0")
            for i in self.shortDistances.index:
                if i in nextNodes.index and i not in self.visited:
                    self.costs.append(getDistance(self.adjMat, currentNode, i))
                    currentNode = i
                    self.visited.append(currentNode)
                    break
            if currentNode == self.to_:
                break
        print(f'{self.visited}\n{self.costs}\nTotal Cost = {sum(self.costs)}')
                    
    def createShortestDistanceDf(self):
        places = []
        straightDistances = []

        for node in self.heuristicMat.index:
            places.append(node)
            straightDistances.append(getDistance(straightDistance, self.to_, node))

        return pd.DataFrame({'sd': straightDistances}, index=places)['sd'].sort_values()

G = Greedy(roadDistance, straightDistance, 'Kakani', 'NamoBuddha')
# G.shortDistances
# Out:
# ['Kakani', 'BuddhaNilkanth', 'PashupatinathTemple', 'Bhaktapur', 'Dhulikhel', 'NamoBuddha']
# [0, 27.1, 8.8, 13.4, 16.4, 13.4]
# Total Cost = 79.10000000000001

# %%
nextNodes = roadDistance[["RatnaPark"]].query("RatnaPark > 0")
nextNodes
# for i in G.shortDistances.index:
#     if i in nextNodes.index:
#         print(i)
#         break
G.shortDistances
# Out:
# BoudhanathStupa              0.00
# PashupatinathTemple          1.68
# SinghaDurbar                 4.58
# BuddhaNilkanth               4.91
# RatnaPark                    4.91
# Thamel                       4.94
# SetoMachendranathTemple      5.35
# IndraChowk                   5.44
# DakshinkaliTemple            5.44
# HanumanDhokaTemple           5.69
# BasantapurTower              5.78
# PatanDurbarSquare            6.51
# SwayambhunathStupa           7.20
# Bhaktapur                    8.79
# Kirtipur                    10.75
# Nagarkot                    13.79
# NationalBotanicalGardens    13.96
# Chandragiri                 14.36
# Kakani                      16.32
# Phulchoki                   17.49
# Dhulikhel                   22.80
# Kulekhani                   24.56
# NamoBuddha                  27.34
# Name: sd, dtype: float64

# %%
nextNodes.index
# Out:
# Index(['HanumanDhokaTemple', 'IndraChowk', 'SetoMachendranathTemple',
#        'RatnaPark', 'SinghaDurbar'],
#       dtype='object', name='')

# %%
G.shortDistances
# Out:
# Bhaktapur                    9.06
# Dhulikhel                   11.43
# BoudhanathStupa             13.79
# BuddhaNilkanth              14.55
# PashupatinathTemple         15.30
# SinghaDurbar                17.93
# NamoBuddha                  17.96
# NationalBotanicalGardens    18.29
# PatanDurbarSquare           18.32
# Thamel                      18.67
# RatnaPark                   18.75
# Phulchoki                   19.01
# HanumanDhokaTemple          19.35
# SetoMachendranathTemple     19.40
# IndraChowk                  19.51
# BasantapurTower             19.56
# SwayambhunathStupa          20.94
# Kirtipur                    23.24
# DakshinkaliTemple           27.10
# Chandragiri                 28.08
# Kakani                      28.24
# Kulekhani                   36.08
# Name: sd, dtype: float64
