# %%
import pandas as pd

# %%
location_df=pd.read_excel('DataSet/KathmanduMap.xlsx')
location_df.head(5)
# Out:
#             Unnamed: 0  PashupatinathTemple  BoudhanathStupa  \
# 0  PashupatinathTemple                  0.0              NaN
# 1      BoudhanathStupa                  NaN              0.0
# 2   SwayambhunathStupa                  NaN              NaN
# 3               Thamel                  NaN              NaN
# 4       KopanMonastery                  NaN              NaN
#
#    SwayambhunathStupa  Thamel  KopanMonastery  DurbarSquareKathmandu  \
# 0                 NaN     NaN             NaN                    NaN
# 1                 NaN     NaN             NaN                    NaN
# 2                 0.0     NaN             NaN                    NaN
# 3                 NaN     0.0             NaN                    NaN
# 4                 NaN     NaN             0.0                    NaN
#
#    HanumanDhokaTemple  KumariHouse  BuddhaNilkanth  ...  Bhaktapur  Chisapani  \
# 0                 NaN          NaN             NaN  ...        NaN        NaN
# ...
